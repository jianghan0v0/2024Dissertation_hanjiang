# %%
fire_types = [
    {"code": 111, "category": "Structure fire", "description": "Building fire. Excludes confined fires (113–118)."},
    {"code": 112, "category": "Structure fire", "description": "Fire in structure, other than in a building. Included are fires on or in piers, quays, or pilings: tunnels or underground connecting structures; bridges, trestles, or overhead elevated structures; transformers, power or utility vaults or equipment; fences; and tents."},
    {"code": 113, "category": "Structure fire", "description": "Cooking fire involving the contents of a cooking vessel without fire extension beyond the vessel."},
    {"code": 114, "category": "Structure fire", "description": "Chimney or flue fire originating in and confined to a chimney or flue. Excludes fires that extend beyond the chimney (111 or 112)."},
    {"code": 115, "category": "Structure fire", "description": "Incinerator overload or malfunction, but flames cause no damage outside the incinerator."},
    {"code": 116, "category": "Structure fire", "description": "Fuel burner/boiler, delayed ignition or malfunction, where flames cause no damage outside the fire box."},
    {"code": 117, "category": "Structure fire", "description": "Commercial compactor fire, confined to contents of compactor. Excluded are home trash compactors."},
    {"code": 118, "category": "Structure fire", "description": "Trash or rubbish fire in a structure, with no flame damage to structure or its contents."},
    {"code": 120, "category": "Fire in mobile property used as a fixed structure", "description": "Fire in mobile property used as a fixed structure, other."},
    {"code": 121, "category": "Fire in mobile property used as a fixed structure", "description": "Fire in mobile home used as a fixed residence. Includes mobile homes when not in transit and used as a structure for residential purposes; and manufactured homes built on a permanent chassis."},
    {"code": 122, "category": "Fire in mobile property used as a fixed structure", "description": "Fire in a motor home, camper, or recreational vehicle when used as a structure. Includes motor homes when not in transit and used as a structure for residential purposes."},
    {"code": 123, "category": "Fire in mobile property used as a fixed structure", "description": "Fire in a portable building, when used at a fixed location. Includes portable buildings used for commerce, industry, or education and trailers used for commercial purposes."},
    {"code": 130, "category": "Mobile property (vehicle) fire", "description": "Mobile property (vehicle) fire, other."},
    {"code": 131, "category": "Mobile property (vehicle) fire", "description": "Passenger vehicle fire. Includes any motorized passenger vehicle, other than a motor home (136) (e.g., pickup trucks, sport utility vehicles, buses)."},
    {"code": 132, "category": "Mobile property (vehicle) fire", "description": "Road freight or transport vehicle fire. Includes commercial freight hauling vehicles and contractor vans or trucks. Examples are moving trucks, plumber vans, and delivery trucks."},
    {"code": 133, "category": "Mobile property (vehicle) fire", "description": "Rail vehicle fire. Includes all rail cars, including intermodal containers and passenger cars that are mounted on a rail car."},
    {"code": 134, "category": "Mobile property (vehicle) fire", "description": "Water vehicle fire. Includes boats, barges, hovercraft, and all other vehicles designed for navigation on water."},
    {"code": 135, "category": "Mobile property (vehicle) fire", "description": "Aircraft fire. Includes fires originating in or on an aircraft, regardless of use."},
    {"code": 136, "category": "Mobile property (vehicle) fire", "description": "Self-propelled motor home or recreational vehicle. Includes only self-propelled motor homes or recreational vehicles when being used in a transport mode. Excludes those used for normal residential use (122)."},
    {"code": 137, "category": "Mobile property (vehicle) fire", "description": "Camper or recreational vehicle (RV) fire, not self-propelled. Includes trailers. Excludes RVs on blocks or used regularly as a fixed building (122) and the vehicle towing the camper or RV or the campers mounted on pick ups (131)."},
    {"code": 138, "category": "Mobile property (vehicle) fire", "description": "Off-road vehicle or heavy equipment fire. Includes dirt bikes, specialty off-road vehicles, earth-moving equipment (bulldozers), and farm equipment."},
    {"code": 140, "category": "Natural vegetation fire", "description": "Natural vegetation fire, other."},
    {"code": 141, "category": "Natural vegetation fire", "description": "Forest, woods, or wildland fire. Includes fires involving vegetative fuels, other than prescribed fire (632), that occur in an area in which development is essentially nonexistent, except for roads, railroads, power lines, and the like. Also includes forests managed for lumber production and fires involving elevated fuels such as tree branches and crowns. Excludes areas in cultivation for agricultural purposes such as tree farms or crops (17x series)."},
    {"code": 142, "category": "Natural vegetation fire", "description": "Brush or brush-and-grass mixture fire. Includes ground fuels lying on or immediately above the ground such as duff, roots, dead leaves, fine dead wood, and downed logs."},
    {"code": 143, "category": "Natural vegetation fire", "description": "Grass fire. Includes fire confined to area characterized by grass ground cover, with little or no involvement of other ground fuels; otherwise, see 142."},
    {"code": 150, "category": "Outside rubbish fire", "description": "Outside rubbish fire, other."},
    {"code": 151, "category": "Outside rubbish fire", "description": "Outside rubbish, trash, or waste fire not included in 152–155. Excludes outside rubbish fires in a container or receptacle (154)."},
    {"code": 152, "category": "Outside rubbish fire", "description": "Garbage dump or sanitary landfill fire."},
    {"code": 153, "category": "Outside rubbish fire", "description": "Construction or demolition landfill fire."},
    {"code": 154, "category": "Outside rubbish fire", "description": "Dumpster or other outside trash receptacle fire. Includes waste material from manufacturing or other production processes. Excludes materials that are not rubbish or have salvage value (161 or 162)."},
    {"code": 155, "category": "Outside rubbish fire", "description": "Outside stationary compactor or compacted trash fire. Includes fires where the only material burning is rubbish. Excludes fires where the compactor is damaged (162)."},
    {"code": 160, "category": "Special outside fire", "description": "Special outside fire, other."},
    {"code": 161, "category": "Special outside fire", "description": "Outside storage fire on residential or commercial/industrial property, not rubbish. Includes recyclable materials at dropoff points."},
    {"code": 162, "category": "Special outside fire", "description": "Outside equipment fire. Includes outside trash compactors, outside HVAC units, and irrigation pumps. Excludes special structures (110 series) and mobile construction equipment (130 series)."},
    {"code": 163, "category": "Special outside fire", "description": "Outside gas or vapor combustion explosion without sustained fire."},
    {"code": 164, "category": "Special outside fire", "description": "Outside mailbox fire. Includes dropoff boxes for delivery services."},
    {"code": 170, "category": "Cultivated vegetation, crop fire", "description": "Cultivated vegetation, crop fire, other."},
    {"code": 171, "category": "Cultivated vegetation, crop fire", "description": "Cultivated grain or crop fire. Includes fires involving corn, wheat, soybeans, rice, and other plants before harvest."},
    {"code": 172, "category": "Cultivated vegetation, crop fire", "description": "Cultivated orchard or vineyard fire."},
    {"code": 173, "category": "Cultivated vegetation, crop fire", "description": "Cultivated trees or nursery stock fire. Includes fires involving Christmas tree farms and plants under cultivation for transport off-site for ornamental use."},
    {"code": 100, "category": "Other fires", "description": "Fire, other."},
]

# 转换为DataFrame
df = pd.DataFrame(fire_types)

# 使用pandas的get_dummies进行One-hot编码
df_encoded = pd.get_dummies(df, columns=['category'])

# 展示编码后的数据
print(df_encoded.head())
# Out:
#    code                                        description  \
# 0   111  Building fire. Excludes confined fires (113–118).
# 1   112  Fire in structure, other than in a building. I...
# 2   113  Cooking fire involving the contents of a cooki...
# 3   114  Chimney or flue fire originating in and confin...
# 4   115  Incinerator overload or malfunction, but flame...
#
#    category_Cultivated vegetation, crop fire  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    category_Fire in mobile property used as a fixed structure  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 可视化每个类别的火灾类型数量
plt.figure(figsize=(12, 6))
sns.countplot(y=df['category'])
plt.title('Distribution of Fire Categories')
plt.xlabel('Count')
plt.ylabel('Fire Category')
plt.show()

# 热图可视化One-hot编码后的数据
plt.figure(figsize=(20, 10))
sns.heatmap(df_encoded.drop(columns=['code', 'description']), cmap='viridis', cbar=False)
plt.title('Heatmap of One-hot Encoded Fire Categories')
plt.xlabel('Fire Category')
plt.ylabel('Sample Index')
plt.xticks(rotation=90)
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 示例数据
data = {
    'PROPERTY_USE_CODES': [
        '111', '112', '113', '114', '115', '116', '110', '121', '122', '123', 
        '124', '129', '120', '131', '134', '130', '141', '142', '143', '144', 
        '140', '151', '152', '154', '155', '150', '161', '162', '160', '171', 
        '173', '174', '170', '181', '182', '183', '185', '186', '180', '100', 
        '210', '211', '213', '215', '241', '254', '255', '256', '200', '311', 
        '321', '322', '323', '331', '332', '341', '342', '343', '340', '361', 
        '363', '365', '300', '419', '429', '439', '449', '459', '460', '462', 
        '464', '400', '511', '519', '529', '539', '549', '557', '559', '564', 
        '569', '571', '579', '581', '580', '592', '593', '596', '599', '500', 
        '614', '615', '610', '629', '631', '632', '635', '639', '642', '644', 
        '645', '647', '648', '640', '655', '659', '669', '679', '600', '700', 
        '807', '808', '816', '819', '839', '849', '880', '881', '882', '888', 
        '891', '898', '899', '800', '919', '921', '922', '926', '931', '935', 
        '936', '937', '938', '941', '946', '940', '951', '952', '961', '962', 
        '963', '965', '960', '972', '973', '974', '981', '982', '983', '984', 
        '900', '000', 'NNN', 'UUU'
    ]
}

df = pd.DataFrame(data)

# 自定义分类
categories = {
    '111': 'Assembly', '112': 'Assembly', '113': 'Assembly', '114': 'Assembly',
    '115': 'Assembly', '116': 'Assembly', '110': 'Assembly', '121': 'Assembly',
    '122': 'Assembly', '123': 'Assembly', '124': 'Assembly', '129': 'Assembly',
    '120': 'Assembly', '131': 'Assembly', '134': 'Assembly', '130': 'Assembly',
    '141': 'Assembly', '142': 'Assembly', '143': 'Assembly', '144': 'Assembly',
    '140': 'Assembly', '151': 'Assembly', '152': 'Assembly', '154': 'Assembly',
    '155': 'Assembly', '150': 'Assembly', '161': 'Assembly', '162': 'Assembly',
    '160': 'Assembly', '171': 'Assembly', '173': 'Assembly', '174': 'Assembly',
    '170': 'Assembly', '181': 'Assembly', '182': 'Assembly', '183': 'Assembly',
    '185': 'Assembly', '186': 'Assembly', '180': 'Assembly', '100': 'Assembly',
    '210': 'Educational', '211': 'Educational', '213': 'Educational', '215': 'Educational',
    '241': 'Educational', '254': 'Educational', '255': 'Educational', '256': 'Educational',
    '200': 'Educational', '311': 'Health Care', '321': 'Health Care', '322': 'Health Care',
    '323': 'Health Care', '331': 'Health Care', '332': 'Health Care', '341': 'Health Care',
    '342': 'Health Care', '343': 'Health Care', '340': 'Health Care', '361': 'Health Care',
    '363': 'Health Care', '365': 'Health Care', '300': 'Health Care', '419': 'Residential',
    '429': 'Residential', '439': 'Residential', '449': 'Residential', '459': 'Residential',
    '460': 'Residential', '462': 'Residential', '464': 'Residential', '400': 'Residential',
    '511': 'Mercantile', '519': 'Mercantile', '529': 'Mercantile', '539': 'Mercantile',
    '549': 'Mercantile', '557': 'Mercantile', '559': 'Mercantile', '564': 'Mercantile',
    '569': 'Mercantile', '571': 'Mercantile', '579': 'Mercantile', '581': 'Mercantile',
    '580': 'Mercantile', '592': 'Mercantile', '593': 'Mercantile', '596': 'Mercantile',
    '599': 'Mercantile', '500': 'Mercantile', '614': 'Industrial', '615': 'Industrial',
    '610': 'Industrial', '629': 'Industrial', '631': 'Industrial', '632': 'Industrial',
    '635': 'Industrial', '639': 'Industrial', '642': 'Industrial', '644': 'Industrial',
    '645': 'Industrial', '647': 'Industrial', '648': 'Industrial', '640': 'Industrial',
    '655': 'Industrial', '659': 'Industrial', '669': 'Industrial', '679': 'Industrial',
    '600': 'Industrial', '700': 'Manufacturing', '807': 'Storage', '808': 'Storage',
    '816': 'Storage', '819': 'Storage', '839': 'Storage', '849': 'Storage', '880': 'Storage',
    '881': 'Storage', '882': 'Storage', '888': 'Storage', '891': 'Storage', '898': 'Storage',
    '899': 'Storage', '800': 'Storage', '919': 'Outside', '921': 'Outside', '922': 'Outside',
    '926': 'Outside', '931': 'Outside', '935': 'Outside', '936': 'Outside', '937': 'Outside',
    '938': 'Outside', '941': 'Outside', '946': 'Outside', '940': 'Outside', '951': 'Outside',
    '952': 'Outside', '961': 'Outside', '962': 'Outside', '963': 'Outside', '965': 'Outside',
    '960': 'Outside', '972': 'Outside', '973': 'Outside', '974': 'Outside', '981': 'Outside',
    '982': 'Outside', '983': 'Outside', '984': 'Outside', '900': 'Outside', '000': 'Other',
    'NNN': 'Other', 'UUU': 'Other'
}

# 映射到自定义分类
df['Category'] = df['PROPERTY_USE_CODES'].map(categories)

# 使用pandas的get_dummies进行one-hot编码
one_hot = pd.get_dummies(df['Category'])

# 将one-hot编码的结果与原数据合并
df = pd.concat([df, one_hot], axis=1)
# 可视化每个类别的频次
plt.figure(figsize=(10, 6))
sns.countplot(y='Category', data=df, order=df['Category'].value_counts().index)
plt.title('Distribution of Property Use Categories')
plt.xlabel('Count')
plt.ylabel('Category')
plt.show()

# 生成热图
plt.figure(figsize=(12, 8))
sns.heatmap(one_hot.T, cmap="YlGnBu", cbar=True)
plt.title('One-Hot Encoding Heatmap of Property Use Categories')
plt.xlabel('Samples')
plt.ylabel('Categories')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
