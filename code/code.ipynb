# %%
import requests
import zipfile
import os
import pandas as pd

# %%
#pip install dask

# %%
# 远程文件的 URL
url = 'https://fema.gov/about/reports-and-data/openfema/nfirs_fire_hazmat_pdr_2022.zip'
# 本地保存的文件名
local_zip_file = 'nfirs_fire_hazmat_pdr_2022.zip'
# 第一级解压缩后的文件夹名
first_extracted_folder = 'nfirs_fire_hazmat_pdr_2022'
# 第二级解压缩后的文件夹名
second_extracted_folder = os.path.join(first_extracted_folder, 'NFIRS_FIRES_2022_102623')
# 需要读取的文件路径
incidentaddress_file = 'NFIRS_FIRES_2022_102623/incidentaddress.txt'
basicincident_file ='NFIRS_FIRES_2022_102623/basicincident.txt'
ffcasualty_file ='NFIRS_FIRES_2022_102623/ffcasualty.txt'
civiliancasualty_file ='NFIRS_FIRES_2022_102623/civiliancasualty.txt'
fireincident_file ='NFIRS_FIRES_2022_102623/fireincident.txt'

# 输出的 CSV 文件路径
#output_csv_file = os.path.join(second_extracted_folder, 'NFIRS_FIRES_2022_102623', 'incidentaddress.csv')

# %%
# 下载文件
response = requests.get(url)
with open(local_zip_file, 'wb') as f:
    f.write(response.content)
print(f"Downloaded {local_zip_file}")
# Out:
# Downloaded nfirs_fire_hazmat_pdr_2022.zip

# %%
# 解压缩第一级文件
with zipfile.ZipFile(local_zip_file, 'r') as zip_ref:
    zip_ref.extractall(first_extracted_folder)
print(f"Extracted files to {first_extracted_folder}")
# Out:
# Extracted files to nfirs_fire_hazmat_pdr_2022

# %%
# 解压缩第二级文件
second_zip_file = os.path.join(first_extracted_folder, 'nfirs_fire_hazmat_pdr_2022', 'NFIRS_FIRES_2022_102623.zip')
with zipfile.ZipFile(second_zip_file, 'r') as zip_ref:
    zip_ref.extractall(second_extracted_folder)
print(f"Extracted files to {second_extracted_folder}")
# Out:
# Extracted files to nfirs_fire_hazmat_pdr_2022/NFIRS_FIRES_2022_102623

# %%
# 列出解压后的目录结构
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print(f"{subindent}{f}")

list_files(second_extracted_folder)
# Out:
# NFIRS_FIRES_2022_102623/
#     incidentaddress.txt
#     fireincident.txt
#     civiliancasualty.txt
#     hazchem.txt
#     arson.txt
#     basicincident.txt
#     hazmat.txt
#     wildlands.txt
#     arsonjuvsub.txt
#     ems.txt
#     hazmatequipinvolved.txt
#     codelookup.txt
#     ffcasualty.txt
#     fdheader.txt
#     hazmobprop.txt
#     basicaid.txt
#     ffequipfail.txt
#     filtered_basicincident.csv
#     arsonagencyreferal.txt

# %%
import os
import dask.dataframe as dd

# 定义文件路径
ffcasualty_path = os.path.join(second_extracted_folder, 'ffcasualty.txt')
civiliancasualty_path = os.path.join(second_extracted_folder, 'civiliancasualty.txt')

# 定义数据类型
dtypes = {
    'INCIDENT_KEY': 'object',
    'STATE': 'object',
    'FDID': 'object',
    'INC_DATE': 'object',
    'INC_NO': 'object',
    'EXP_NO': 'object',
    'FF_SEQ_NO': 'object',
    'VERSION': 'float64',
    'GENDER': 'object',
    'CAREER': 'float64',
    'PABI': 'object',
    'CAUSE': 'object',
    'FACTOR': 'object',
    'OBJECT': 'object',
    'WIO': 'object',
    'RELATION': 'object',
    'STORY': 'object',
    'LOCATION': 'object',
    'VEHICLE': 'object',
    'PROT_EQP': 'object',
    'SEQ_NUMBER': 'object',
    'AGE': 'float64',
    'FACT_INJ3': 'object',
    'ACTIV_INJ': 'object',
    'LOC_INC': 'object',
    'GEN_LOC_IN': 'object',
    'STORY_INC': 'object',
    'STORY_INJ': 'object',
    'SPC_LOC_IN': 'object',
    'PRIM_SYMP': 'object',
    'BODY_PART': 'object',
    'CC_DISPOS': 'object',
    'ACTIVITY': 'object',
    'PHYS_COND': 'object',
    'SEVERITY': 'object',
    'SYMPTOM': 'object',
    'CAUSE_INJ': 'object',
       'RACE': 'object',
       'SEV': 'object'
}

def read_large_file_with_dask(file_path, delimiter='^', encoding='latin1', dtypes=None):
    try:
        return dd.read_csv(file_path, delimiter=delimiter, encoding=encoding, dtype=dtypes)
    except Exception as e:
        print(f"Error reading the file {file_path}: {e}")
        return None

# 检查文件路径并读取文件
files = [
    ('ffcasualty', ffcasualty_path),
    ('civiliancasualty', civiliancasualty_path)
]

data_frames = {}

for name, path in files:
    if os.path.exists(path):
        print(f"Reading {name} from {path}...")
        data_frames[name] = read_large_file_with_dask(path, dtypes=dtypes)
    else:
        print(f"Error: The file at path {path} does not exist.")

# 检查是否成功读取数据框
if not data_frames:
    print("No data frames were loaded. Please check the file paths and try again.")
else:
    # 合并数据框
    merged_df = None
    for key, df in data_frames.items():
        if df is not None:
            if merged_df is None:
                merged_df = df
            else:
                merged_df = dd.merge(merged_df, df, on='INCIDENT_KEY', how='outer', suffixes=('', f'_{key}'))

    if merged_df is not None:
        # 将合并后的数据框保存到一个新文件
        print("Merged Data Frame:")
        print(merged_df.head())
        
        output_path = os.path.join(second_extracted_folder, 'merged_data.csv')
        merged_df.compute().to_csv(output_path, index=False)
        print(f"Merged data saved to {output_path}")
    else:
        print("Merging data frames failed. Please check the input files for consistency.")
# Out:
# Reading ffcasualty from nfirs_fire_hazmat_pdr_2022/NFIRS_FIRES_2022_102623/ffcasualty.txt...
# Reading civiliancasualty from nfirs_fire_hazmat_pdr_2022/NFIRS_FIRES_2022_102623/civiliancasualty.txt...
# Merged Data Frame:
#                  INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO EXP_NO FF_SEQ_NO  \
# 0  AK_11100_05222022_223075_0    AK  11100  05222022  223075      0         1
# 1  AK_11100_11262022_227808_0    AK  11100  11262022  227808      0         1
# 2  AK_11100_11262022_227808_0    AK  11100  11262022  227808      0         2
# 3  AK_11100_11262022_227808_0    AK  11100  11262022  227808      0         3
# 4  AK_11100_12202022_228285_0    AK  11100  12202022  228285      0         1
#
#    VERSION GENDER  CAREER  ...  FACT_INJ3  ACTIV_INJ  LOC_INC  GEN_LOC_IN  \
# 0      5.0      1     1.0  ...       <NA>       <NA>     <NA>        <NA>
# 1      5.0      2     1.0  ...       <NA>       <NA>     <NA>        <NA>
# 2      5.0      1     1.0  ...       <NA>       <NA>     <NA>        <NA>
# 3      5.0      2     2.0  ...       <NA>       <NA>     <NA>        <NA>
# 4      5.0      1     1.0  ...       <NA>       <NA>     <NA>        <NA>
#
#   STORY_INC STORY_INJ SPC_LOC_IN PRIM_SYMP BODY_PART CC_DISPOS
# 0      <NA>      <NA>       <NA>      <NA>      <NA>      <NA>
# 1      <NA>      <NA>       <NA>      <NA>      <NA>      <NA>
# 2      <NA>      <NA>       <NA>      <NA>      <NA>      <NA>
# 3      <NA>      <NA>       <NA>      <NA>      <NA>      <NA>
# 4      <NA>      <NA>       <NA>      <NA>      <NA>      <NA>
#
# [5 rows x 64 columns]
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# /opt/conda/lib/python3.11/site-packages/partd/pandas.py:141: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   elif is_datetime64tz_dtype(block):
# Merged data saved to nfirs_fire_hazmat_pdr_2022/NFIRS_FIRES_2022_102623/merged_data.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(merged_data.csv)
#
# NameError: name 'merged_data' is not defined

# %%
# 洛杉矶县城市列表
la_cities = [
    "Agoura Hills", "Alhambra", "Arcadia", "Artesia", "Avalon", "Azusa", "Baldwin Park", "Bell", "Bell Gardens", "Bellflower",
    "Beverly Hills", "Bradbury", "Burbank", "Calabasas", "Carson", "Cerritos", "Claremont", "Commerce", "Compton", "Covina",
    "Cudahy", "Culver City", "Diamond Bar", "Downey", "Duarte", "El Monte", "El Segundo", "Gardena", "Glendale", "Glendora",
    "Hawaiian Gardens", "Hawthorne", "Hermosa Beach", "Hidden Hills", "Huntington Park", "Industry", "Inglewood", "Irwindale",
    "La Cañada Flintridge", "La Habra Heights", "La Mirada", "La Puente", "La Verne", "Lakewood", "Lancaster", "Lawndale",
    "Lomita", "Long Beach", "Los Angeles", "Lynwood", "Malibu", "Manhattan Beach", "Maywood", "Monrovia", "Montebello",
    "Monterey Park", "Norwalk", "Palmdale", "Palos Verdes Estates", "Paramount", "Pasadena", "Pico Rivera", "Pomona",
    "Rancho Palos Verdes", "Redondo Beach", "Rolling Hills", "Rolling Hills Estates", "Rosemead", "San Dimas", "San Fernando",
    "San Gabriel", "San Marino", "Santa Clarita", "Santa Fe Springs", "Santa Monica", "Sierra Madre", "Signal Hill",
    "South El Monte", "South Gate", "South Pasadena", "Temple City", "Torrance", "Vernon", "Walnut", "West Covina",
    "West Hollywood", "Westlake Village", "Whittier"
]

# %%
import os
import pandas as pd

# 定义文件路径
incidentaddress_path = os.path.join(second_extracted_folder, 'incidentaddress.txt')
basicincident_path = os.path.join(second_extracted_folder,  'basicincident.txt')
ffcasualty_path = os.path.join(second_extracted_folder, 'ffcasualty.txt')
civiliancasualty_path = os.path.join(second_extracted_folder,  'civiliancasualty.txt')
fireincident_path = os.path.join(second_extracted_folder, 'fireincident.txt')

def read_large_file(file_path, delimiter='^', encoding='latin1'):
    try:
        chunk_size = 10000  # 每次读取10000行
        reader = pd.read_csv(file_path, delimiter=delimiter, encoding=encoding, chunksize=chunk_size)
        for chunk in reader:
            print(chunk.head(10))
            # 在这里可以对每个chunk进行处理
    except UnicodeDecodeError as e:
        print(f"Error reading the file {file_path} with 'latin1' encoding: {e}")
    except Exception as e:
        print(f"Error reading the file {file_path}: {e}")


# 读取第三个文件
if os.path.exists(ffcasualty_path):
    print("Firefighter casualty Data:")
    read_large_file(ffcasualty_path)
else:
    print(f"Error: The file at path {ffcasualty_path} does not exist.")

# 读取第一个文件
if os.path.exists(civiliancasualty_path):
    print("Civilian casualty Data:")
    read_large_file(civiliancasualty_path)
else:
    print(f"Error: The file at path {civiliancasualty_path} does not exist.")

# 读取第一个文件
if os.path.exists(fireincident_path):
    print("Fire Incident Data:")
    read_large_file(fireincident_path)
else:
    print(f"Error: The file at path {fireincident_path} does not exist.")

# 读取第一个文件
if os.path.exists(incidentaddress_path):
    print("Incident Address Data:")
    read_large_file(incidentaddress_path)
else:
    print(f"Error: The file at path {incidentaddress_path} does not exist.")

# 读取第二个文件
if os.path.exists(basicincident_path):
    print("Basic Incident Data:")
    read_large_file(basicincident_path)
else:
    print(f"Error: The file at path {basicincident_path} does not exist.")
# Out:
# Firefighter casualty Data:
#                   INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 0   AK_11100_05222022_223075_0    AK  11100   5222022  223075       0
# 1   AK_11100_11262022_227808_0    AK  11100  11262022  227808       0
# 2   AK_11100_11262022_227808_0    AK  11100  11262022  227808       0
# 3   AK_11100_11262022_227808_0    AK  11100  11262022  227808       0
# 4   AK_11100_12202022_228285_0    AK  11100  12202022  228285       0
# 5     AK_13000_10132022_2088_0    AK  13000  10132022    2088       0
# 6     AK_13000_10132022_2088_0    AK  13000  10132022    2088       0
# 7  AK_15100_05032022_0000009_0    AK  15100   5032022       9       0
# 8  AK_19702_10202022_0102022_0    AK  19702  10202022  102022       0
# 9  AK_19702_10202022_0102022_0    AK  19702  10202022  102022       0
#
#    FF_SEQ_NO  VERSION  GENDER  CAREER  ...  PABI  CAUSE  FACTOR  OBJECT WIO  \
# 0          1      5.0       1     1.0  ...    61      7     NaN      27   6
# 1          1      5.0       2     1.0  ...    73      6      54      13   5
# 2          2      5.0       1     1.0  ...    10      6      UU      UU   6
# 3          3      5.0       2     2.0  ...    65      0      UU      43   6
# 4          1      5.0       1     1.0  ...    65      6     NaN      32   6
# 5          1      5.0       1     1.0  ...    81      4      NN     NaN   0
# 6          2      5.0       1     1.0  ...    81      4      NN     NaN   0
# 7          1      5.0       2     NaN  ...    63      1      UU      26   6
# 8          1      5.0       1     NaN  ...    81      4     NaN      NN   6
# 9          2      5.0       1     NaN  ...    32      4     NaN     NaN   6
#
#   RELATION STORY LOCATION VEHICLE PROT_EQP
# 0      NaN   NaN      NaN     NaN        N
# 1      1.0   2.0       49     NaN        N
# 2      2.0   1.0       UU     NaN        N
# 3      2.0   0.0       22     NaN        N
# 4      2.0   1.0       22     NaN        N
# 5      2.0   NaN       22     NaN        N
# 6      2.0   NaN       22     NaN        N
# 7      2.0   NaN      NaN       1        N
# 8      NaN   NaN       22     NaN        N
# 9      NaN   NaN       22     NaN        N
#
# [10 rows x 29 columns]
# Civilian casualty Data:
#                   INCIDENT_KEY STATE   FDID  INC_DATE   INC_NO  EXP_NO  \
# 0   AK_11100_03272022_221850_0    AK  11100   3272022   221850       0
# 1   AK_11100_05302022_223295_0    AK  11100   5302022   223295       0
# 2   AK_11100_11072022_227420_0    AK  11100  11072022   227420       0
# 3     AK_13000_08242022_1726_0    AK  13000   8242022     1726       0
# 4  AK_13000_12062022_2201888_0    AK  13000  12062022  2201888       0
# 5  AK_15100_04212022_0000007_0    AK  15100   4212022        7       0
# 6  AK_15100_06022022_0000025_0    AK  15100   6022022       25       0
# 7  AK_17200_07212022_0072122_0    AK  17200   7212022    72122       0
# 8  AK_17200_07212022_0072122_0    AK  17200   7212022    72122       0
# 9  AK_19702_02232022_0022322_0    AK  19702   2232022    22322       0
#
#    SEQ_NUMBER  VERSION  GENDER   AGE  ... FACT_INJ3  ACTIV_INJ  LOC_INC  \
# 0           1      5.0     1.0  47.0  ...       NaN          4        1
# 1           1      5.0     1.0  58.0  ...       NaN          4        2
# 2           1      5.0     1.0  70.0  ...       NaN          6        2
# 3           1      5.0     1.0  35.0  ...       NaN          4        3
# 4           1      5.0     2.0  12.0  ...       NaN          1      NaN
# 5           1      5.0     2.0  68.0  ...       NaN          0        1
# 6           1      5.0     1.0  52.0  ...       NaN          3      NaN
# 7           1      5.0     1.0  28.0  ...       NaN          3      NaN
# 8           2      5.0     1.0  35.0  ...       NaN          3      NaN
# 9           1      5.0     2.0  61.0  ...       NaN        NaN      NaN
#
#    GEN_LOC_IN STORY_INC STORY_INJ SPC_LOC_IN  PRIM_SYMP  BODY_PART  CC_DISPOS
# 0         NaN       NaN       NaN         81         01          8        NaN
# 1           2       1.0       1.0         05         01          8          1
# 2           2       1.0       1.0         09         11          6          1
# 3           3       1.0       1.0         24         11          6          1
# 4         NaN       NaN       NaN        NaN        NaN          0        NaN
# 5           1       NaN       NaN        NaN         12          9          1
# 6         NaN       NaN       NaN        NaN        NaN          7          N
# 7         NaN       NaN       NaN        NaN         01          8          N
# 8         NaN       NaN       NaN        NaN         01          8          N
# 9         NaN       NaN       NaN        NaN         12          6          N
#
# [10 rows x 36 columns]
# Fire Incident Data:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (14,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (14,25,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (41,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
#                  INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  VERSION  \
# 0   AK_11100_01012022_22004_0    AK  11100   1012022   22004       0      5.0
# 1   AK_11100_01082022_22170_0    AK  11100   1082022   22170       0      5.0
# 2   AK_11100_02132022_22985_0    AK  11100   2132022   22985       0      5.0
# 3  AK_11100_02202022_221148_0    AK  11100   2202022  221148       0      5.0
# 4  AK_11100_02242022_221244_0    AK  11100   2242022  221244       0      5.0
# 5  AK_11100_03072022_221457_0    AK  11100   3072022  221457       0      5.0
# 6  AK_11100_03082022_221487_0    AK  11100   3082022  221487       0      5.0
# 7  AK_11100_03182022_221666_0    AK  11100   3182022  221666       0      5.0
# 8  AK_11100_03272022_221850_0    AK  11100   3272022  221850       0      5.0
# 9  AK_11100_04122022_222184_0    AK  11100   4122022  222184       0      5.0
#
#    NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER DET_OPERAT  \
# 0       0.0       N         0.0  ...       NaN       NaN        NaN
# 1       NaN       N         NaN  ...       NaN       NaN        NaN
# 2       NaN       N         NaN  ...       NaN       NaN        NaN
# 3       NaN       N         NaN  ...       NaN       NaN        NaN
# 4       NaN       Y         NaN  ...       NaN       NaN        NaN
# 5       0.0       N         NaN  ...       NaN       NaN        NaN
# 6       NaN       Y         0.0  ...       NaN       NaN        NaN
# 7       NaN       N         NaN  ...       NaN       NaN        NaN
# 8       0.0       Y         NaN  ...       NaN       NaN        NaN
# 9       0.0       N         1.0  ...       NaN       NaN        NaN
#
#   DET_EFFECT DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP AES_FAIL
# 0        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 1        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 2        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 3        NaN      NaN        N       NaN      NaN       NaN      NaN
# 4        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 5        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 6        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 7        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 8        NaN      NaN      NaN       NaN      NaN       NaN      NaN
# 9        NaN      NaN        N       NaN      NaN       NaN      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE  FDID  INC_DATE  INC_NO  EXP_NO  \
# 10000  AL_03102_07042022_0004355_0    AL  3102   7042022    4355       0
# 10001  AL_03102_07122022_0004531_0    AL  3102   7122022    4531       0
# 10002  AL_03102_07122022_0004549_0    AL  3102   7122022    4549       0
# 10003  AL_03102_07192022_0005139_0    AL  3102   7192022    5139       0
# 10004  AL_03102_08052022_0005216_0    AL  3102   8052022    5216       0
# 10005  AL_03102_08062022_0005226_0    AL  3102   8062022    5226       0
# 10006  AL_03102_08082022_0005292_0    AL  3102   8082022    5292       0
# 10007  AL_03102_08132022_0005408_0    AL  3102   8132022    5408       0
# 10008  AL_03102_08132022_0005415_0    AL  3102   8132022    5415       0
# 10009  AL_03102_08142022_0005427_0    AL  3102   8142022    5427       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 10000      5.0       1.0       N         NaN  ...       NaN       NaN
# 10001      5.0       2.0       N         NaN  ...       NaN       NaN
# 10002      5.0       1.0       N         NaN  ...         1         4
# 10003      5.0       NaN       N         NaN  ...       NaN       NaN
# 10004      5.0       0.0       Y         NaN  ...       NaN       NaN
# 10005      5.0       0.0       Y         NaN  ...       NaN       NaN
# 10006      5.0       0.0       Y         NaN  ...       NaN       NaN
# 10007      5.0       0.0       Y         NaN  ...       NaN       NaN
# 10008      5.0       NaN       N         NaN  ...       NaN       NaN
# 10009      5.0       NaN       N         NaN  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 10000        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10001        NaN        NaN      NaN        N       NaN      NaN       NaN
# 10002          2          1      NaN        N       NaN      NaN       NaN
# 10003        NaN        NaN      NaN        U       NaN      NaN       NaN
# 10004        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10005        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10006        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10007        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10008        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 10009        NaN        NaN      NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 10000      NaN
# 10001      NaN
# 10002      NaN
# 10003      NaN
# 10004      NaN
# 10005      NaN
# 10006      NaN
# 10007      NaN
# 10008      NaN
# 10009      NaN
#
# [10 rows x 81 columns]
#                    INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 20000  AR_26001_09272022_1201_0    AR  26001   9272022    1201       0
# 20001  AR_26001_09292022_1209_0    AR  26001   9292022    1209       0
# 20002  AR_26001_09302022_1212_0    AR  26001   9302022    1212       0
# 20003  AR_26001_10072022_1241_0    AR  26001  10072022    1241       0
# 20004  AR_26001_10182022_1285_0    AR  26001  10182022    1285       0
# 20005  AR_26001_10192022_1290_0    AR  26001  10192022    1290       0
# 20006  AR_26001_10192022_1291_0    AR  26001  10192022    1291       0
# 20007  AR_26001_10212022_1299_0    AR  26001  10212022    1299       0
# 20008  AR_26001_10252022_1314_0    AR  26001  10252022    1314       0
# 20009  AR_26001_10292022_1341_0    AR  26001  10292022    1341       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 20000      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20001      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20002      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20003      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20004      5.0       8.0       N         0.0  ...       NaN       NaN
# 20005      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20006      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20007      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20008      5.0       0.0       Y         0.0  ...       NaN       NaN
# 20009      5.0       1.0       N         3.0  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 20000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20006        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 20009        NaN        NaN       NaN        N       NaN      NaN       NaN
#
#       AES_FAIL
# 20000      NaN
# 20001      NaN
# 20002      NaN
# 20003      NaN
# 20004      NaN
# 20005      NaN
# 20006      NaN
# 20007      NaN
# 20008      NaN
# 20009      NaN
#
# [10 rows x 81 columns]
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (15,17,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (15,17,52,75,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (25,37,40,41,75,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
#                       INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 30000  AR_72600_10222022_0010786_0    AR  72600  10222022   10786       0
# 30001  AR_72600_10232022_0010839_0    AR  72600  10232022   10839       0
# 30002  AR_72600_10292022_0011054_0    AR  72600  10292022   11054       0
# 30003  AR_72600_10302022_0011123_0    AR  72600  10302022   11123       0
# 30004  AR_72600_10302022_0011131_0    AR  72600  10302022   11131       0
# 30005  AR_72600_11012022_0011190_0    AR  72600  11012022   11190       0
# 30006  AR_72600_11022022_0011232_0    AR  72600  11022022   11232       0
# 30007  AR_72600_11042022_0011291_0    AR  72600  11042022   11291       0
# 30008  AR_72600_11052022_0011341_0    AR  72600  11052022   11341       0
# 30009  AR_72600_11062022_0011392_0    AR  72600  11062022   11392       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 30000      5.0       1.0       N         1.0  ...       NaN       NaN
# 30001      5.0       1.0       N         1.0  ...         1         U
# 30002      5.0       0.0       Y         0.0  ...       NaN       NaN
# 30003      5.0       0.0       Y         0.0  ...       NaN       NaN
# 30004      5.0       1.0       N         1.0  ...       NaN       NaN
# 30005      5.0       0.0       Y         0.0  ...       NaN       NaN
# 30006      5.0       1.0       N         1.0  ...         1         4
# 30007      5.0       0.0       Y         0.0  ...       NaN       NaN
# 30008      5.0       1.0       N         1.0  ...         1         U
# 30009      5.0       0.0       Y         0.0  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 30000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 30001          2          1       NaN        N       NaN      NaN       NaN
# 30002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 30003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 30004        NaN        NaN       NaN        N       NaN      NaN       NaN
# 30005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 30006          2          1       NaN        1         1        1       1.0
# 30007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 30008          1        NaN       NaN        N       NaN      NaN       NaN
# 30009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 30000      NaN
# 30001      NaN
# 30002      NaN
# 30003      NaN
# 30004      NaN
# 30005      NaN
# 30006      NaN
# 30007      NaN
# 30008      NaN
# 30009      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE  FDID  INC_DATE   INC_NO  EXP_NO  \
# 40000   AZ_08311_12122022_121107_0    AZ  8311  12122022   121107       0
# 40001   AZ_08311_12262022_122606_0    AZ  8311  12262022   122606       0
# 40002  AZ_08365_03172022_2026855_0    AZ  8365   3172022  2026855       0
# 40003  AZ_08365_07132022_2069353_0    AZ  8365   7132022  2069353       0
# 40004  AZ_08365_08092022_2079024_0    AZ  8365   8092022  2079024       0
# 40005  AZ_08365_08162022_2081367_0    AZ  8365   8162022  2081367       0
# 40006  AZ_08365_10232022_2104504_0    AZ  8365  10232022  2104504       0
# 40007  AZ_08365_12072022_2121137_0    AZ  8365  12072022  2121137       0
# 40008  AZ_08423_01032022_2004312_0    AZ  8423   1032022  2004312       0
# 40009  AZ_08423_01042022_2005937_0    AZ  8423   1042022  2005937       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 40000      5.0       0.0       Y         0.0  ...       NaN       NaN
# 40001      5.0       0.0       Y         0.0  ...       NaN       NaN
# 40002      5.0       NaN       N         NaN  ...       NaN       NaN
# 40003      5.0       0.0       N         1.0  ...       NaN       NaN
# 40004      5.0       1.0       N         NaN  ...         4         4
# 40005      5.0       0.0       Y         1.0  ...       NaN       NaN
# 40006      5.0       1.0       N         1.0  ...       NaN       NaN
# 40007      5.0       2.0       N         1.0  ...       NaN       NaN
# 40008      5.0       0.0       N         NaN  ...       NaN       NaN
# 40009      5.0       0.0       N         NaN  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 40000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 40001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 40002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 40003        NaN        NaN       NaN        N       NaN      NaN       NaN
# 40004          2          3       NaN        1       NaN      NaN       NaN
# 40005        NaN        NaN       NaN        N       NaN      NaN       NaN
# 40006        NaN        NaN       NaN        N       NaN      NaN       NaN
# 40007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 40008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 40009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 40000      NaN
# 40001      NaN
# 40002      NaN
# 40003      NaN
# 40004      NaN
# 40005      NaN
# 40006      NaN
# 40007      NaN
# 40008      NaN
# 40009      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE   FDID  INC_DATE   INC_NO  EXP_NO  \
# 50000  CA_10030_10292022_2087516_0    CA  10030  10292022  2087516       0
# 50001  CA_10030_10302022_2087554_0    CA  10030  10302022  2087554       0
# 50002  CA_10030_10302022_2087582_0    CA  10030  10302022  2087582       0
# 50003  CA_10030_10302022_2087584_0    CA  10030  10302022  2087584       0
# 50004  CA_10030_10302022_2087592_0    CA  10030  10302022  2087592       0
# 50005  CA_10030_10302022_2087639_0    CA  10030  10302022  2087639       0
# 50006  CA_10030_10302022_2087650_0    CA  10030  10302022  2087650       0
# 50007  CA_10030_10302022_2087677_0    CA  10030  10302022  2087677       0
# 50008  CA_10030_10302022_2087682_0    CA  10030  10302022  2087682       0
# 50009  CA_10030_10302022_2087685_0    CA  10030  10302022  2087685       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 50000      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50001      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50002      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50003      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50004      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50005      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50006      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50007      5.0       1.0     NaN         NaN  ...       NaN       NaN
# 50008      5.0       NaN     NaN         NaN  ...       NaN       NaN
# 50009      5.0       NaN     NaN         NaN  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 50000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50006        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 50009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 50000      NaN
# 50001      NaN
# 50002      NaN
# 50003      NaN
# 50004      NaN
# 50005      NaN
# 50006      NaN
# 50007      NaN
# 50008      NaN
# 50009      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 60000  CA_19105_02232022_0000753_0    CA  19105   2232022     753       0
# 60001  CA_19105_02232022_0000853_0    CA  19105   2232022     853       0
# 60002  CA_19105_02232022_0000858_0    CA  19105   2232022     858       0
# 60003  CA_19105_02232022_0000997_0    CA  19105   2232022     997       0
# 60004  CA_19105_02232022_0000999_0    CA  19105   2232022     999       0
# 60005  CA_19105_02232022_0001127_0    CA  19105   2232022    1127       0
# 60006  CA_19105_02232022_0001160_0    CA  19105   2232022    1160       0
# 60007  CA_19105_02232022_0001160_1    CA  19105   2232022    1160       1
# 60008  CA_19105_02232022_0001160_2    CA  19105   2232022    1160       2
# 60009  CA_19105_02232022_0001160_3    CA  19105   2232022    1160       3
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 60000      5.0       NaN     NaN         0.0  ...       NaN       NaN
# 60001      5.0       NaN     NaN         0.0  ...       NaN       NaN
# 60002      5.0       0.0       Y         0.0  ...       NaN       NaN
# 60003      5.0       0.0       Y         0.0  ...       NaN       NaN
# 60004      5.0       0.0       Y         0.0  ...       NaN       NaN
# 60005      5.0       NaN     NaN         0.0  ...       NaN       NaN
# 60006      5.0      18.0     NaN         1.0  ...       NaN       NaN
# 60007      5.0      18.0     NaN         0.0  ...       NaN       NaN
# 60008      5.0      18.0     NaN         0.0  ...       NaN       NaN
# 60009      5.0      18.0     NaN         0.0  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 60000        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60001        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60002        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60003        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60004        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60005        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 60006        NaN        NaN      NaN        U       NaN      NaN       NaN
# 60007        NaN        NaN      NaN        U       NaN      NaN       NaN
# 60008        NaN        NaN      NaN        U       NaN      NaN       NaN
# 60009        NaN        NaN      NaN        U       NaN      NaN       NaN
#
#       AES_FAIL
# 60000      NaN
# 60001      NaN
# 60002      NaN
# 60003      NaN
# 60004      NaN
# 60005      NaN
# 60006      NaN
# 60007      NaN
# 60008      NaN
# 60009      NaN
#
# [10 rows x 81 columns]
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (14,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (15,17,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (15,37,49,50,68,69,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
#                       INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 70000  CA_19200_11182022_0014925_0    CA  19200  11182022   14925       0
# 70001  CA_19200_11202022_0014997_0    CA  19200  11202022   14997       0
# 70002  CA_19200_11232022_0015119_0    CA  19200  11232022   15119       0
# 70003  CA_19200_11262022_0015293_0    CA  19200  11262022   15293       0
# 70004  CA_19200_11282022_0015392_0    CA  19200  11282022   15392       0
# 70005  CA_19200_12062022_0015794_0    CA  19200  12062022   15794       0
# 70006  CA_19200_12072022_0015828_0    CA  19200  12072022   15828       0
# 70007  CA_19200_12082022_0015882_0    CA  19200  12082022   15882       0
# 70008  CA_19200_12152022_0016202_0    CA  19200  12152022   16202       0
# 70009  CA_19200_12172022_0016308_0    CA  19200  12172022   16308       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 70000      5.0       NaN       Y         NaN  ...       NaN       NaN
# 70001      5.0       NaN       Y         0.0  ...       NaN       NaN
# 70002      5.0       NaN       Y         NaN  ...       NaN       NaN
# 70003      5.0       1.0       N         1.0  ...         1         1
# 70004      5.0       NaN       Y         1.0  ...       NaN       NaN
# 70005      5.0       NaN       Y         NaN  ...         4         0
# 70006      5.0       NaN       Y         1.0  ...         5         U
# 70007      5.0       NaN       Y         NaN  ...       NaN       NaN
# 70008      5.0       NaN       Y         NaN  ...       NaN       NaN
# 70009      5.0       NaN       Y         NaN  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 70000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 70001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 70002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 70003          U        NaN       NaN        N       NaN      NaN       NaN
# 70004        NaN        NaN       NaN        U       NaN      NaN       NaN
# 70005          2          1       NaN        1         4        1       3.0
# 70006          2          1       NaN        1         1        4       NaN
# 70007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 70008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 70009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 70000      NaN
# 70001      NaN
# 70002      NaN
# 70003      NaN
# 70004      NaN
# 70005      NaN
# 70006        5
# 70007      NaN
# 70008      NaN
# 70009      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 80000  CA_33090_04052022_0049691_0    CA  33090   4052022   49691       0
# 80001  CA_33090_04052022_0049750_0    CA  33090   4052022   49750       0
# 80002  CA_33090_04052022_0049757_0    CA  33090   4052022   49757       0
# 80003  CA_33090_04062022_0049844_0    CA  33090   4062022   49844       0
# 80004  CA_33090_04062022_0050064_0    CA  33090   4062022   50064       0
# 80005  CA_33090_04062022_0050195_0    CA  33090   4062022   50195       0
# 80006  CA_33090_04072022_0050676_0    CA  33090   4072022   50676       0
# 80007  CA_33090_04072022_0050742_0    CA  33090   4072022   50742       0
# 80008  CA_33090_04072022_0050858_0    CA  33090   4072022   50858       0
# 80009  CA_33090_04092022_0051591_0    CA  33090   4092022   51591       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 80000      5.0       0.0       N         NaN  ...       NaN       NaN
# 80001      5.0       NaN       N         NaN  ...       NaN       NaN
# 80002      5.0       0.0       N         0.0  ...       NaN       NaN
# 80003      5.0       NaN       N         NaN  ...       NaN       NaN
# 80004      5.0       0.0       Y         NaN  ...       NaN       NaN
# 80005      5.0       NaN       N         NaN  ...       NaN       NaN
# 80006      5.0       NaN       N         NaN  ...       NaN       NaN
# 80007      5.0       5.0       N         NaN  ...       NaN       NaN
# 80008      5.0       NaN       N         NaN  ...       NaN       NaN
# 80009      5.0       NaN       N         NaN  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 80000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80006        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 80009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#       AES_FAIL
# 80000      NaN
# 80001      NaN
# 80002      NaN
# 80003      NaN
# 80004      NaN
# 80005      NaN
# 80006      NaN
# 80007      NaN
# 80008      NaN
# 80009      NaN
#
# [10 rows x 81 columns]
#                       INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 90000  CA_37090_01212022_0000652_0    CA  37090   1212022     652       0
# 90001  CA_37090_01282022_0000827_0    CA  37090   1282022     827       0
# 90002  CA_37090_02062022_0001091_0    CA  37090   2062022    1091       0
# 90003  CA_37090_02112022_0001219_0    CA  37090   2112022    1219       0
# 90004  CA_37090_02122022_0001240_0    CA  37090   2122022    1240       0
# 90005  CA_37090_02122022_0001245_0    CA  37090   2122022    1245       0
# 90006  CA_37090_02122022_0001253_0    CA  37090   2122022    1253       0
# 90007  CA_37090_02262022_0001659_0    CA  37090   2262022    1659       0
# 90008  CA_37090_02272022_0001694_0    CA  37090   2272022    1694       0
# 90009  CA_37090_03072022_0001903_0    CA  37090   3072022    1903       0
#
#        VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 90000      5.0       NaN       N         NaN  ...       NaN       NaN
# 90001      5.0       NaN       N         NaN  ...       NaN       NaN
# 90002      5.0       NaN       N         NaN  ...       NaN       NaN
# 90003      5.0       NaN       N         NaN  ...       NaN       NaN
# 90004      5.0       0.0       Y         NaN  ...       NaN       NaN
# 90005      5.0       0.0       Y         NaN  ...       NaN       NaN
# 90006      5.0       0.0       Y         0.0  ...       NaN       NaN
# 90007      5.0       0.0       Y         NaN  ...       NaN       NaN
# 90008      5.0       NaN       N         NaN  ...       NaN       NaN
# 90009      5.0       0.0       Y         0.0  ...       NaN       NaN
#
#       DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE  AES_OPER NO_SPR_OP  \
# 90000        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90001        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90002        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90003        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90004        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90005        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90006        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90007        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90008        NaN        NaN       NaN      NaN       NaN       NaN       NaN
# 90009        NaN        NaN       NaN      NaN       NaN       NaN       NaN
#
#       AES_FAIL
# 90000      NaN
# 90001      NaN
# 90002      NaN
# 90003      NaN
# 90004      NaN
# 90005      NaN
# 90006      NaN
# 90007      NaN
# 90008      NaN
# 90009      NaN
#
# [10 rows x 81 columns]
#                     INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 100000  CA_39105_10202022_2247_0    CA  39105  10202022    2247       0
# 100001  CA_39105_10202022_2249_0    CA  39105  10202022    2249       0
# 100002  CA_39105_10202022_2251_0    CA  39105  10202022    2251       0
# 100003  CA_39105_10212022_2255_0    CA  39105  10212022    2255       0
# 100004  CA_39105_10222022_2261_0    CA  39105  10222022    2261       0
# 100005  CA_39105_10222022_2265_0    CA  39105  10222022    2265       0
# 100006  CA_39105_10222022_2268_0    CA  39105  10222022    2268       0
# 100007  CA_39105_10222022_2269_0    CA  39105  10222022    2269       0
# 100008  CA_39105_10222022_2271_0    CA  39105  10222022    2271       0
# 100009  CA_39105_10232022_2273_0    CA  39105  10232022    2273       0
#
#         VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 100000      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100001      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100002      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100003      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100004      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100005      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100006      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100007      5.0       1.0       N         1.0  ...       NaN       NaN
# 100008      5.0       0.0       Y         0.0  ...       NaN       NaN
# 100009      5.0       0.0       Y         0.0  ...       NaN       NaN
#
#        DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 100000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100006        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100007        NaN        NaN       NaN        N       NaN      NaN       NaN
# 100008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 100009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#        AES_FAIL
# 100000      NaN
# 100001      NaN
# 100002      NaN
# 100003      NaN
# 100004      NaN
# 100005      NaN
# 100006      NaN
# 100007      NaN
# 100008      NaN
# 100009      NaN
#
# [10 rows x 81 columns]
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (14,15,17,25,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# /tmp/ipykernel_89353/265101855.py:15: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
#                      INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 110000  CA_54045_01082022_22311_0    CA  54045   1082022   22311       0
# 110001  CA_54045_01082022_22312_0    CA  54045   1082022   22312       0
# 110002  CA_54045_01082022_22317_0    CA  54045   1082022   22317       0
# 110003  CA_54045_01082022_22325_0    CA  54045   1082022   22325       0
# 110004  CA_54045_01142022_22611_0    CA  54045   1142022   22611       0
# 110005  CA_54045_01142022_22630_0    CA  54045   1142022   22630       0
# 110006  CA_54045_01172022_22791_0    CA  54045   1172022   22791       0
# 110007  CA_54045_01202022_22931_0    CA  54045   1202022   22931       0
# 110008  CA_54045_01212022_22944_0    CA  54045   1212022   22944       0
# 110009  CA_54045_01212022_22944_1    CA  54045   1212022   22944       1
#
#         VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 110000      5.0       3.0       N         NaN  ...       NaN       NaN
# 110001      5.0       3.0       N         NaN  ...       NaN       NaN
# 110002      5.0       1.0       N         1.0  ...         1         1
# 110003      5.0       1.0       Y         1.0  ...       NaN       NaN
# 110004      5.0       NaN       Y         NaN  ...       NaN       NaN
# 110005      5.0       NaN       N         0.0  ...       NaN       NaN
# 110006      5.0       1.0       Y         1.0  ...       NaN       NaN
# 110007      5.0       NaN       Y         NaN  ...       NaN       NaN
# 110008      5.0       0.0       Y         NaN  ...       NaN       NaN
# 110009      5.0       0.0       Y         NaN  ...       NaN       NaN
#
#        DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 110000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110001        NaN        NaN       NaN        N       NaN      NaN       NaN
# 110002          2          1       NaN        N       NaN      NaN       NaN
# 110003        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110005        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110006        NaN        NaN       NaN        N       NaN      NaN       NaN
# 110007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 110009        NaN        NaN       NaN        N       NaN      NaN       NaN
#
#        AES_FAIL
# 110000      NaN
# 110001      NaN
# 110002      NaN
# 110003      NaN
# 110004      NaN
# 110005      NaN
# 110006      NaN
# 110007      NaN
# 110008      NaN
# 110009      NaN
#
# [10 rows x 81 columns]
#                     INCIDENT_KEY STATE  FDID  INC_DATE  INC_NO  EXP_NO  \
# 120000  CO_04305_07132022_2268_0    CO  4305   7132022    2268       0
# 120001  CO_04305_07192022_2348_0    CO  4305   7192022    2348       0
# 120002  CO_04305_07192022_2349_0    CO  4305   7192022    2349       0
# 120003  CO_04305_07202022_2332_0    CO  4305   7202022    2332       0
# 120004  CO_04305_07222022_2362_0    CO  4305   7222022    2362       0
# 120005  CO_04305_07282022_2418_0    CO  4305   7282022    2418       0
# 120006  CO_04305_08072022_2538_0    CO  4305   8072022    2538       0
# 120007  CO_04305_08102022_2555_0    CO  4305   8102022    2555       0
# 120008  CO_04305_08132022_2581_0    CO  4305   8132022    2581       0
# 120009  CO_04305_08132022_2626_0    CO  4305   8132022    2626       0
#
#         VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 120000      5.0       0.0       Y         0.0  ...       NaN       NaN
# 120001      5.0       0.0       Y         0.0  ...       NaN       NaN
# 120002      5.0       0.0       Y         0.0  ...       NaN       NaN
# 120003      5.0       0.0       Y         0.0  ...       NaN       NaN
# 120004      5.0       0.0       Y         0.0  ...       NaN       NaN
# 120005      5.0       1.0       N         1.0  ...       NaN       NaN
# 120006      5.0       2.0       N         1.0  ...       NaN       NaN
# 120007      5.0       1.0       N         0.0  ...       NaN       NaN
# 120008      5.0       1.0       N         0.0  ...       NaN       NaN
# 120009      5.0       0.0       Y         0.0  ...       NaN       NaN
#
#        DET_OPERAT DET_EFFECT  DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 120000        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120001        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120002        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120003        NaN        NaN       NaN        N       NaN      NaN       NaN
# 120004        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120005        NaN        NaN       NaN        N       NaN      NaN       NaN
# 120006        NaN        NaN       NaN        N       NaN      NaN       NaN
# 120007        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120008        NaN        NaN       NaN      NaN       NaN      NaN       NaN
# 120009        NaN        NaN       NaN      NaN       NaN      NaN       NaN
#
#        AES_FAIL
# 120000      NaN
# 120001      NaN
# 120002      NaN
# 120003      NaN
# 120004      NaN
# 120005      NaN
# 120006      NaN
# 120007      NaN
# 120008      NaN
# 120009      NaN
#
# [10 rows x 81 columns]
#                        INCIDENT_KEY STATE  FDID  INC_DATE   INC_NO  EXP_NO  \
# 130000  CT_08056_12032022_1001155_0    CT  8056  12032022  1001155       0
# 130001  CT_08060_02082022_0000294_0    CT  8060   2082022      294       0
# 130002  CT_08060_02112022_0000370_0    CT  8060   2112022      370       0
# 130003  CT_08060_02122022_0000456_0    CT  8060   2122022      456       0
# 130004  CT_08060_04252022_0000780_0    CT  8060   4252022      780       0
# 130005  CT_08060_05142022_0000908_0    CT  8060   5142022      908       0
# 130006  CT_08060_05282022_0001010_0    CT  8060   5282022     1010       0
# 130007  CT_08060_07042022_0001212_0    CT  8060   7042022     1212       0
# 130008  CT_08060_07122022_0001280_0    CT  8060   7122022     1280       0
# 130009  CT_08060_07302022_0001419_0    CT  8060   7302022     1419       0
#
#         VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 130000      5.0       1.0       N         NaN  ...       NaN       NaN
# 130001      5.0       1.0       N         1.0  ...         1         2
# 130002      5.0       NaN       N         NaN  ...       NaN       NaN
# 130003      5.0       NaN       N         NaN  ...       NaN       NaN
# 130004      5.0       0.0       Y         NaN  ...       NaN       NaN
# 130005      5.0       0.0       Y         0.0  ...       NaN       NaN
# 130006      5.0       1.0       N         NaN  ...         1         1
# 130007      5.0       1.0       N         1.0  ...         1         1
# 130008      5.0       0.0       Y         0.0  ...       NaN       NaN
# 130009      5.0       NaN       N         0.0  ...       NaN       NaN
#
#        DET_OPERAT DET_EFFECT DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 130000        NaN        NaN      NaN        N       NaN      NaN       NaN
# 130001          3        NaN        0        N       NaN      NaN       NaN
# 130002        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 130003        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 130004        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 130005        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 130006          2          4      NaN        N       NaN      NaN       NaN
# 130007          3        NaN        U        N       NaN      NaN       NaN
# 130008        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 130009        NaN        NaN      NaN      NaN       NaN      NaN       NaN
#
#        AES_FAIL
# 130000      NaN
# 130001      NaN
# 130002      NaN
# 130003      NaN
# 130004      NaN
# 130005      NaN
# 130006      NaN
# 130007      NaN
# 130008      NaN
# 130009      NaN
#
# [10 rows x 81 columns]
#                      INCIDENT_KEY STATE  FDID  INC_DATE  INC_NO  EXP_NO  \
# 140000  FL_05032_06142022_12959_0    FL  5032   6142022   12959       0
# 140001  FL_05032_06142022_12995_0    FL  5032   6142022   12995       0
# 140002  FL_05032_06152022_13029_0    FL  5032   6152022   13029       0
# 140003  FL_05032_06152022_13042_0    FL  5032   6152022   13042       0
# 140004  FL_05032_06152022_13075_0    FL  5032   6152022   13075       0
# 140005  FL_05032_06162022_13189_0    FL  5032   6162022   13189       0
# 140006  FL_05032_06172022_13278_0    FL  5032   6172022   13278       0
# 140007  FL_05032_06182022_13328_0    FL  5032   6182022   13328       0
# 140008  FL_05032_06182022_13339_0    FL  5032   6182022   13339       0
# 140009  FL_05032_06192022_13413_0    FL  5032   6192022   13413       0
#
#         VERSION  NUM_UNIT NOT_RES  BLDG_INVOL  ...  DET_TYPE DET_POWER  \
# 140000      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140001      5.0       1.0       N         0.0  ...       NaN       NaN
# 140002      5.0       1.0       N         0.0  ...       NaN       NaN
# 140003      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140004      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140005      5.0      50.0       N         0.0  ...       NaN       NaN
# 140006      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140007      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140008      5.0       NaN       Y         0.0  ...       NaN       NaN
# 140009      5.0       NaN       Y         0.0  ...       NaN       NaN
#
#        DET_OPERAT DET_EFFECT DET_FAIL AES_PRES  AES_TYPE AES_OPER NO_SPR_OP  \
# 140000        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140001        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140002        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140003        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140004        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140005        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140006        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140007        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140008        NaN        NaN      NaN      NaN       NaN      NaN       NaN
# 140009        NaN        NaN      NaN      NaN       NaN      NaN       NaN
#
#        AES_FAIL
# 140000      NaN
# 140001      NaN
# 140002      NaN
# 140003      NaN
# 140004      NaN
# 140005      NaN
# 140006      NaN
# 140007      NaN
# 140008      NaN
# 140009      NaN
#
# [10 rows x 81 columns]
#                        INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 150000  FL_14162_04302022_0036279_0    FL  14162   4302022   36279       0
# ...
# 2320004  WI_36070_05132022_22431_0    WI  36070   5132022   22431       0
# 2320005  WI_36070_05132022_22433_0    WI  36070   5132022   22433       0
# 2320006  WI_36070_05152022_22439_0    WI  36070   5152022   22439       0
# 2320007  WI_36070_05162022_22444_0    WI  36070   5162022   22444       0
# 2320008  WI_36070_05172022_22455_0    WI  36070   5172022   22455       0
# 2320009  WI_36070_05192022_22467_0    WI  36070   5192022   22467       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2320000      5.0        2       142        N  ...      0.0       0.0
# 2320001      5.0        1       151        N  ...      0.0       0.0
# 2320002      5.0        1       111        N  ...    250.0       0.0
# 2320003      5.0        1       424        N  ...      0.0       0.0
# 2320004      5.0        3       463        N  ...      0.0       0.0
# 2320005      5.0        3       111        N  ...   2000.0       0.0
# 2320006      5.0        2       100        N  ...      0.0       0.0
# 2320007      5.0        1       113        N  ...      0.0       0.0
# 2320008      5.0        2       100        N  ...      0.0       0.0
# 2320009      5.0        4       422        N  ...      0.0       0.0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT HAZ_REL MIXED_USE  PROP_USE  \
# 2320000        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2320001        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2320002        NaN     0.0      NaN       NaN     NaN       NaN       400
# 2320003        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2320004        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2320005        NaN     0.0      NaN       NaN     NaN       NaN       965
# 2320006        NaN     0.0      NaN         1     NaN       NaN       429
# 2320007        NaN     0.0      NaN         1     NaN       NaN       439
# 2320008        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2320009        NaN     0.0      NaN       NaN     NaN       NaN       700
#
#         CENSUS
# 2320000    NaN
# 2320001    NaN
# 2320002    NaN
# 2320003    NaN
# 2320004    NaN
# 2320005    NaN
# 2320006    NaN
# 2320007    NaN
# 2320008    NaN
# 2320009    NaN
#
# [10 rows x 42 columns]
#                         INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 2330000  WI_44140_06152022_0000016_0    WI  44140   6152022      16       0
# 2330001  WI_44140_06152022_0000018_0    WI  44140   6152022      18       0
# 2330002  WI_44140_06152022_0000019_0    WI  44140   6152022      19       0
# 2330003  WI_44140_06152022_0000020_0    WI  44140   6152022      20       0
# 2330004  WI_44140_06152022_0000021_0    WI  44140   6152022      21       0
# 2330005  WI_44140_06152022_0000022_0    WI  44140   6152022      22       0
# 2330006  WI_44140_06152022_0000023_0    WI  44140   6152022      23       0
# 2330007  WI_44140_06152022_0000024_0    WI  44140   6152022      24       0
# 2330008  WI_44140_06152022_0000027_0    WI  44140   6152022      27       0
# 2330009  WI_44140_06152022_0000032_0    WI  44140   6152022      32       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2330000      5.0      NaN       444        N  ...      NaN       0.0
# 2330001      5.0      NaN       461        N  ...      NaN       0.0
# 2330002      5.0      NaN       444        N  ...      NaN       0.0
# 2330003      5.0      NaN       444        N  ...      NaN       0.0
# 2330004      5.0      NaN       444        N  ...      NaN       0.0
# 2330005      5.0      NaN       444        N  ...      NaN       0.0
# 2330006      5.0      NaN       444        N  ...      NaN       0.0
# 2330007      5.0      NaN       444        N  ...      NaN       0.0
# 2330008      5.0      NaN       444        N  ...      NaN       0.0
# 2330009      5.0      NaN       445        N  ...      NaN       0.0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT HAZ_REL MIXED_USE  PROP_USE  \
# 2330000        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330001        NaN     0.0      NaN       NaN     NaN       NaN       655
# 2330002        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330003        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2330004        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330005        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330006        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330007        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330008        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2330009        NaN     0.0      NaN       NaN     NaN       NaN       419
#
#          CENSUS
# 2330000     NaN
# 2330001     NaN
# 2330002     NaN
# 2330003     NaN
# 2330004     NaN
# 2330005     NaN
# 2330006     NaN
# 2330007     NaN
# 2330008     NaN
# 2330009     NaN
#
# [10 rows x 42 columns]
#                         INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 2340000  WI_67090_10302022_0000997_0    WI  67090  10302022     997       0
# 2340001  WI_67090_10312022_0001000_0    WI  67090  10312022    1000       0
# 2340002  WI_67090_11042022_0001025_0    WI  67090  11042022    1025       0
# 2340003  WI_67090_11052022_0001029_0    WI  67090  11052022    1029       0
# 2340004  WI_67090_11052022_0001031_0    WI  67090  11052022    1031       0
# 2340005  WI_67090_11052022_0001034_0    WI  67090  11052022    1034       0
# 2340006  WI_67090_11072022_0001039_0    WI  67090  11072022    1039       0
# 2340007  WI_67090_11142022_0001068_0    WI  67090  11142022    1068       0
# 2340008  WI_67090_11182022_0001090_0    WI  67090  11182022    1090       0
# 2340009  WI_67090_11202022_0001098_0    WI  67090  11202022    1098       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2340000      5.0        1       151        N  ...      0.0       0.0
# 2340001      5.0        1       440        N  ...      0.0       0.0
# 2340002      5.0        1       131        N  ...      0.0       0.0
# 2340003      5.0        1       444        N  ...      0.0       0.0
# 2340004      5.0        1       444        N  ...      0.0       0.0
# 2340005      5.0        1       444        N  ...      0.0       0.0
# 2340006      5.0        1       440        N  ...      0.0       0.0
# 2340007      5.0        1       150        N  ...      1.0       0.0
# 2340008      5.0        1       424        N  ...      0.0       0.0
# 2340009      5.0        1       111        N  ...      0.0       0.0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT HAZ_REL MIXED_USE  PROP_USE  \
# 2340000        NaN     0.0      NaN       NaN     NaN       NaN       900
# 2340001        NaN     0.0      NaN       NaN     NaN       NaN       400
# 2340002        NaN     0.0      NaN       NaN     NaN       NaN       961
# 2340003        NaN     0.0      NaN       NaN     NaN       NaN       400
# 2340004        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2340005        NaN     0.0      NaN       NaN     NaN       NaN       962
# 2340006        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2340007        NaN     0.0      NaN       NaN     NaN       NaN       400
# 2340008        NaN     0.0      NaN       NaN     NaN       NaN       419
# 2340009        NaN     0.0      NaN         1     NaN       NaN       419
#
#          CENSUS
# 2340000   BTF01
# 2340001   BTF01
# 2340002   BTF01
# 2340003   BTF01
# 2340004   BTF01
# 2340005   BTF01
# 2340006   BTF01
# 2340007   BTF01
# 2340008   BTF01
# 2340009   BCF01
#
# [10 rows x 42 columns]
#                         INCIDENT_KEY STATE   FDID  INC_DATE   INC_NO  EXP_NO  \
# 2350000  WV_17221_02192022_0013431_0    WV  17221   2192022    13431       0
# 2350001  WV_17221_02192022_0013671_0    WV  17221   2192022    13671       0
# 2350002  WV_17221_02262022_2015770_0    WV  17221   2262022  2015770       0
# 2350003  WV_17221_03012022_2016450_0    WV  17221   3012022  2016450       0
# 2350004  WV_17221_03052022_0017580_0    WV  17221   3052022    17580       0
# 2350005  WV_17221_03052022_0017887_0    WV  17221   3052022    17887       0
# 2350006  WV_17221_03062022_0017987_0    WV  17221   3062022    17987       0
# 2350007  WV_17221_03102022_2019237_0    WV  17221   3102022  2019237       0
# 2350008  WV_17221_03122022_0019790_0    WV  17221   3122022    19790       0
# 2350009  WV_17221_03152022_0020719_0    WV  17221   3152022    20719       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2350000      5.0       22       444        N  ...      NaN       0.0
# 2350001      5.0       21       461        N  ...      NaN       0.0
# 2350002      5.0       24       440        N  ...      NaN       0.0
# 2350003      5.0       22       445        N  ...      NaN       0.0
# 2350004      5.0       22       411        N  ...      NaN       0.0
# 2350005      5.0       24       462        N  ...      NaN       0.0
# 2350006      5.0       22       561        N  ...      NaN       0.0
# 2350007      5.0       22       422        N  ...      NaN       0.0
# 2350008      5.0       21       111        N  ...  10000.0       0.0
# 2350009      5.0       22       561        N  ...      NaN       0.0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT  HAZ_REL MIXED_USE  PROP_USE  \
# 2350000        NaN     0.0      NaN       NaN      NaN       NaN       419
# 2350001        NaN     0.0      NaN       NaN      NaN       NaN       938
# 2350002        NaN     0.0      NaN         U      NaN       NaN       419
# 2350003        NaN     0.0      NaN       NaN      NaN       NaN       642
# 2350004        NaN     0.0      NaN       NaN      NaN       NaN       963
# 2350005        NaN     0.0      NaN       NaN      NaN       NaN       888
# 2350006        NaN     0.0      NaN       NaN      NaN       NaN       419
# 2350007        NaN     0.0      NaN       NaN      NaN       NaN       965
# 2350008        NaN     0.0      NaN         1      NaN       NaN       419
# 2350009        NaN     0.0      NaN       NaN      NaN       NaN       419
#
#          CENSUS
# 2350000     NaN
# 2350001  540310
# 2350002     NaN
# 2350003  540310
# 2350004     NaN
# 2350005  540310
# 2350006     NaN
# 2350007  540310
# 2350008  540310
# 2350009     NaN
#
# [10 rows x 42 columns]
#                     INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 2360000  WV_35106_08012022_576_0    WV  35106   8012022     576       0
# 2360001  WV_35106_08012022_577_0    WV  35106   8012022     577       0
# 2360002  WV_35106_08042022_583_0    WV  35106   8042022     583       0
# 2360003  WV_35106_08112022_593_0    WV  35106   8112022     593       0
# 2360004  WV_35106_08302022_639_0    WV  35106   8302022     639       0
# 2360005  WV_35106_08312022_642_0    WV  35106   8312022     642       0
# 2360006  WV_35106_09042022_651_0    WV  35106   9042022     651       0
# 2360007  WV_35106_09192022_698_0    WV  35106   9192022     698       0
# 2360008  WV_35106_09272022_719_0    WV  35106   9272022     719       0
# 2360009  WV_35106_09282022_721_0    WV  35106   9282022     721       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2360000      5.0      F50       440        N  ...      0.0       0.0
# 2360001      5.0      F50       444        N  ...      0.0       0.0
# 2360002      5.0      F50       444        N  ...      0.0       0.0
# 2360003      5.0      F50       131        N  ...      0.0       0.0
# 2360004      5.0      F50       111        N  ...      0.0       0.0
# 2360005      5.0      F50       444        N  ...      0.0       0.0
# 2360006      5.0      F50       444        N  ...      0.0       0.0
# 2360007      5.0      F50       131        N  ...      0.0       0.0
# 2360008      5.0      F50       463        N  ...      0.0       0.0
# 2360009      5.0      F50       111        N  ...      0.0       0.0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT  HAZ_REL  MIXED_USE  PROP_USE  \
# 2360000        NaN     0.0      NaN         U        N        NaN       419
# 2360001        NaN     0.0      NaN         U        N        NaN       419
# 2360002        NaN     0.0      NaN         U        N        NaN       419
# 2360003        NaN     0.0      NaN         U        N        NaN       419
# 2360004        NaN     0.0      NaN         U        N        NaN       580
# 2360005        NaN     0.0      NaN         U        N        NaN       419
# 2360006        NaN     0.0      NaN         U        N        NaN       419
# 2360007        NaN     0.0      NaN         U        N        NaN       961
# 2360008        NaN     0.0      NaN         U        N        NaN       419
# 2360009        NaN     0.0      NaN         U        N        NaN       160
#
#          CENSUS
# 2360000     NaN
# 2360001     NaN
# 2360002     NaN
# 2360003     NaN
# 2360004     NaN
# 2360005     NaN
# 2360006     NaN
# 2360007     NaN
# 2360008     NaN
# 2360009     NaN
#
# [10 rows x 42 columns]
#                        INCIDENT_KEY STATE   FDID  INC_DATE  INC_NO  EXP_NO  \
# 2370000    WY_35520_01102022_0226_0    WY  35520   1102022     226       0
# 2370001   WY_35520_01172022_00372_0    WY  35520   1172022     372       0
# 2370002   WY_35520_01202022_00419_0    WY  35520   1202022     419       0
# 2370003   WY_35520_01202022_00424_0    WY  35520   1202022     424       0
# 2370004   WY_35520_01202022_00432_0    WY  35520   1202022     432       0
# 2370005   WY_35520_01302022_00629_0    WY  35520   1302022     629       0
# 2370006     WY_35520_02232022_865_0    WY  35520   2232022     865       0
# 2370007   WY_35520_03122022_01537_0    WY  35520   3122022    1537       0
# 2370008   WY_35520_03172022_01630_0    WY  35520   3172022    1630       0
# 2370009  WY_35520_03222022_017323_0    WY  35520   3222022   17323       0
#
#          VERSION DEPT_STA  INC_TYPE ADD_WILD  ... CONT_VAL  FF_DEATH  \
# 2370000      5.0        4       412        N  ...      0.0         0
# 2370001      5.0        2       412        N  ...      0.0         0
# 2370002      5.0        2       412        N  ...      0.0         0
# 2370003      5.0        5       114        N  ...      0.0         0
# 2370004      5.0        1       412        N  ...      0.0         0
# 2370005      5.0        5       160        N  ...      0.0         0
# 2370006      5.0        1       412        N  ...      0.0         0
# 2370007      5.0        1       412        N  ...      0.0         0
# 2370008      5.0        2       424        N  ...      0.0         0
# 2370009      5.0        1       424        N  ...      0.0         0
#
#          OTH_DEATH  FF_INJ  OTH_INJ DET_ALERT  HAZ_REL MIXED_USE  PROP_USE  \
# 2370000        NaN       0      NaN         U        N       NaN       400
# 2370001        NaN       0      NaN         U        N       NaN       400
# 2370002        NaN       0      NaN         U        N       NaN       400
# 2370003        NaN       0      NaN         U        N       NaN       400
# 2370004        NaN       0      NaN         U        N       NaN       400
# 2370005        NaN       0      NaN         U        N       NaN       150
# 2370006        NaN       0      NaN         U        N       NaN       150
# 2370007        NaN       0      NaN         U        N       NaN       419
# 2370008        NaN       0      NaN         U        N       NaN       400
# 2370009        NaN       0      NaN         U        N       NaN       150
#
#          CENSUS
# 2370000     NaN
# 2370001     NaN
# 2370002     NaN
# 2370003     NaN
# 2370004     NaN
# 2370005     NaN
# 2370006     NaN
# 2370007     NaN
# 2370008     NaN
# 2370009     NaN
#
# [10 rows x 42 columns]

# %%
import os
import pandas as pd

# 定义文件路径
incidentaddress_path = os.path.join(second_extracted_folder, 'incidentaddress.txt')
basicincident_path = os.path.join(second_extracted_folder,  'basicincident.txt')
ffcasualty_path = os.path.join(second_extracted_folder, 'ffcasualty.txt')
civiliancasualty_path = os.path.join(second_extracted_folder,  'civiliancasualty.txt')
fireincident_path = os.path.join(second_extracted_folder, 'fireincident.txt')

def read_large_file(file_path, delimiter='^', encoding='latin1'):
    try:
        chunk_size = 10000  # 每次读取10000行
        chunks = []
        reader = pd.read_csv(file_path, delimiter=delimiter, encoding=encoding, chunksize=chunk_size)
        for chunk in reader:
            chunks.append(chunk)
        return pd.concat(chunks, ignore_index=True)
    except UnicodeDecodeError as e:
        print(f"Error reading the file {file_path} with 'latin1' encoding: {e}")
        return None
    except Exception as e:
        print(f"Error reading the file {file_path}: {e}")
        return None

# 读取所有文件并存储在字典中
data_frames = {}

if os.path.exists(ffcasualty_path):
    data_frames['ffcasualty'] = read_large_file(ffcasualty_path)
else:
    print(f"Error: The file at path {ffcasualty_path} does not exist.")

if os.path.exists(civiliancasualty_path):
    data_frames['civiliancasualty'] = read_large_file(civiliancasualty_path)
else:
    print(f"Error: The file at path {civiliancasualty_path} does not exist.")

if os.path.exists(fireincident_path):
    data_frames['fireincident'] = read_large_file(fireincident_path)
else:
    print(f"Error: The file at path {fireincident_path} does not exist.")

if os.path.exists(incidentaddress_path):
    data_frames['incidentaddress'] = read_large_file(incidentaddress_path)
else:
    print(f"Error: The file at path {incidentaddress_path} does not exist.")

if os.path.exists(basicincident_path):
    data_frames['basicincident'] = read_large_file(basicincident_path)
else:
    print(f"Error: The file at path {basicincident_path} does not exist.")

# 检查所有数据帧是否读取成功
for key, df in data_frames.items():
    if df is None:
        print(f"Failed to read the data frame for {key}")
    else:
        print(f"Successfully read the data frame for {key}")

# 合并数据框
merged_df = None
for key, df in data_frames.items():
    if merged_df is None:
        merged_df = df
    else:
        merged_df = pd.merge(merged_df, df, on='INCIDENT_KEY', how='outer')

# 打印合并后的数据框的前几行
print("Merged Data Frame:")
print(merged_df.head())

# 保存合并后的数据框到一个新文件
output_path = os.path.join(second_extracted_folder, 'merged_data.csv')
merged_df.to_csv(output_path, index=False, encoding='latin1')
print(f"Merged data saved to {output_path}")
